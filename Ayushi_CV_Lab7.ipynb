# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
imgL = cv2.imread("/content/Left_image.png", 0)
plt.imshow(imgL,"gray")
print(imgL.shape)
# Out:
# (256, 256)

# %%
imgR = cv2.imread("/content/Right_image.png", 0)
plt.imshow(imgR,"gray")
print(imgR.shape)
# Out:
# (256, 256)

# %%
stereo = cv2.StereoBM_create(numDisparities=16, blockSize=5)
disparity = stereo.compute(imgL, imgR).astype(np.float32)/16
print(f"Range: {np.min(disparity)} <-> {np.max(disparity)}")
plt.imshow(disparity, "gray")
plt.show()
# Out:
# Range: -1.0 <-> 15.0

# %%
baseline = 0.1
focal_length = 0.8

depth_map= np.zeros_like(disparity ,dtype=np.float32)
depth_map[disparity > 0]=focal_length*baseline/disparity[disparity > 0]

plt.imshow(depth_map,"gray")
